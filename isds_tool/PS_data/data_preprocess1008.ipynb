# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import shutil
from pathlib import Path
import pandas as pd
from tqdm import tqdm

sys.path.append(r'E:\repository\dataset_tools\isds_tool\PS_data')
from google_drive_tools import download_all_subfolders_parallel
from zip_tools import uzip_dirs, zip_folder_to_path, uzip_file
from yolo_tools import att_check, find_defect, copy_all

# %%
root_dir = r'\\158.132.186.40\isds\huilin\isds\google_drive_data\task1008'
merge_dir = os.path.join(root_dir, 'merge_dir')
root_folder_id = '1_8deZ7H8mTHOqKH8oToREi5ZWLVCzp1Z'
client_secret = r"E:\data\202502_signboard\data_annotation\docs\client_secret.json"
token_path = r'E:\repository\dataset_tools\isds_tool\PS_data\token.json'

gap_num = 3

# %%
# os.remove(token_path)

# %%
download_all_subfolders_parallel(token_path, client_secret, root_folder_id, root_dir)
# Out:
# 将并发下载 5 个子文件夹...
#
#
# 📁 Starting folder: 12-33-54_PM
#
# 📁 Starting folder: 01-04-56_PM
#
# 📁 Starting folder: 02-11-49_PM
#
# 📁 Starting folder: 02-26-55_PM
#
# 📁 Starting folder: 12-52-08_PM
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\gps_data.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\slam_geo_referenced.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\poses_tum_converted.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\step1_raw_trajectories.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\geo_ref_matrix.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\slam_geo_referenced_snapped.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\gps_data.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\poses_tum_converted.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\gps_data.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\slam_geo_referenced.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\step2_converted_gps_hk1980.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\slam_geo_referenced_snapped_manual.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\slam_geo_referenced_snapped.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\slam_geo_referenced.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\cameras.zip
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\14-26-55.pcd
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\slam_geo_referenced_snapped.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\step1_raw_trajectories.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\slam_geo_referenced.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\step2_converted_gps_hk1980.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\poses_tum_converted.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\12-52-08.pcd
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\gps_data.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\gps_data.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras.zip
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\gps_data.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\step2_converted_gps_hk1980.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\step3_only_georeferenced_slam.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\slam_geo_referenced.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\slam_geo_referenced_snapped.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\slam_geo_referenced_snapped.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\slam_geo_referenced_snapped_manual.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\cameras.zip
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\step3_only_georeferenced_slam.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\gps_data.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\slam_geo_referenced.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\gps_data.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\slam_geo_referenced_snapped_manual.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\slam_geo_referenced_snapped.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\slam_geo_referenced_snapped.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\slam_geo_referenced.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\14-11-49.pcd
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\step1_raw_trajectories.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\poses_tum_converted.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\step2_converted_gps_hk1980.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\.state\images.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\.state\corrector.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\.state\slam.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\.state\map_match.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\.state\rename.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\.state\timesync.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\slam_geo_referenced_snapped.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\.state\slam.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras.zip
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\.state\timesync.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\13-04-56.pcd
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\.state\rename.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\.state\map_match.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\slam_geo_referenced_snapped_manual.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\.state\corrector.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\geo_ref_matrix.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\.state\images.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\step2_converted_gps_hk1980.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-26-55_PM\step3_only_georeferenced_slam.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\step1_raw_trajectories.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\step3_only_georeferenced_slam.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\slam_geo_referenced.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\gps_data.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\slam_geo_referenced_snapped.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\.state\images.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\.state\timesync.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\.state\rename.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\.state\corrector.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\.state\slam.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\.state\map_match.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\slam_geo_referenced_snapped.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\slam_geo_referenced_snapped_manual.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\gps_data.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\geo_ref_matrix.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\slam_geo_referenced.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras.zip
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\step3_only_georeferenced_slam.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\.state\images.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\.state\corrector.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\.state\slam.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\.state\rename.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\.state\timesync.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\.state\map_match.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\poses_tum_converted.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\12-33-54.pcd
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\step1_raw_trajectories.png
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\slam_geo_referenced.html
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\geo_ref_matrix.txt
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\.state\images.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\.state\map_match.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\.state\rename.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\.state\slam.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\.state\corrector.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\.state\timesync.complete
# ⚠️ 已存在，跳过: \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\02-11-49_PM\geo_ref_matrix.txt

# %%
# uzip_dirs(root_dir, zip_relative_path='cameras.zip')

# %%
from img_preprocess import select_img
from deduplication_demo import filter_deduplication

def process_dirs(root_dir):
    sub_dirs = os.listdir(root_dir)
    for idx, sub_name in enumerate(sub_dirs):
        sub_dir = os.path.join(root_dir, sub_name)
        if not os.path.isdir(sub_dir) or sub_name.startswith('r'):
            continue
        cam_name_list = ['camera1', 'camera2', 'camera3', 'camera4', 'camera5', 'camera6']
        for cam_name in cam_name_list:
            image_dir_src = os.path.join(sub_dir, 'cameras', cam_name)
            if not os.path.exists(image_dir_src):
                print(f'{image_dir_src} not exists')
            else:
                print(f'{image_dir_src} selecting...')
                image_dir_select = image_dir_src+'_select'
                shutil.rmtree(image_dir_select) if os.path.exists(image_dir_select) else None
                select_img(image_dir_src, image_dir_select, gap=gap_num)
                print(f'{image_dir_select} filtering...')
                image_dir_filter = image_dir_src+'_filter'
                shutil.rmtree(image_dir_filter) if os.path.exists(image_dir_filter) else None
                filter_deduplication(image_dir_select, image_dir_filter)
                print(f'{image_dir_filter} done\n')

# %%
process_dirs(root_dir)
# Out:
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera1 selecting...
# 100%|██████████| 1385/1385 [01:06<00:00, 20.83it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera1_select filtering...
# 100%|██████████| 1385/1385 [03:26<00:00,  6.71it/s]
# 100%|██████████| 957/957 [00:47<00:00, 20.02it/s]
# Total unique images copied: 957
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera1_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera2 selecting...
# 100%|██████████| 1385/1385 [01:00<00:00, 22.73it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera2_select filtering...
# 100%|██████████| 1385/1385 [03:06<00:00,  7.41it/s]
# 100%|██████████| 603/603 [00:29<00:00, 20.70it/s]
# Total unique images copied: 603
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera2_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera3 selecting...
# 100%|██████████| 1385/1385 [00:58<00:00, 23.71it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM\cameras\camera3_select filtering...
# 100%|██████████| 1385/1385 [03:13<00:00,  7.15it/s]
# 100%|██████████| 758/758 [00:34<00:00, 21.71it/s]
# Total unique images copied: 758
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\01-04-56_PM
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera4 selecting...
# 100%|██████████| 1104/1104 [00:55<00:00, 19.73it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera4_select filtering...
# 100%|██████████| 1104/1104 [04:03<00:00,  4.53it/s]
# 100%|██████████| 369/369 [00:21<00:00, 17.12it/s]
# Total unique images copied: 369
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera4_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera5 selecting...
# 100%|██████████| 1104/1104 [00:57<00:00, 19.33it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera5_select filtering...
# 100%|██████████| 1104/1104 [04:04<00:00,  4.51it/s]
# 100%|██████████| 566/566 [00:32<00:00, 17.25it/s]
# Total unique images copied: 566
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera5_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera6 selecting...
# 100%|██████████| 1104/1104 [01:02<00:00, 17.67it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera6_select filtering...
# 100%|██████████| 1104/1104 [04:08<00:00,  4.45it/s]
# 100%|██████████| 720/720 [00:47<00:00, 15.28it/s]
# Total unique images copied: 720
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-33-54_PM\cameras\camera6_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera1 selecting...
# 100%|██████████| 756/756 [00:41<00:00, 18.19it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera1_select filtering...
# 100%|██████████| 756/756 [02:52<00:00,  4.39it/s]
# 100%|██████████| 573/573 [00:34<00:00, 16.47it/s]
# Total unique images copied: 573
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera1_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera2 selecting...
# 100%|██████████| 756/756 [00:40<00:00, 18.73it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera2_select filtering...
# 100%|██████████| 756/756 [02:48<00:00,  4.49it/s]
# 100%|██████████| 341/341 [00:19<00:00, 17.28it/s]
# Total unique images copied: 341
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera2_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera3 selecting...
# 100%|██████████| 756/756 [00:38<00:00, 19.52it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera3_select filtering...
# 100%|██████████| 756/756 [02:53<00:00,  4.37it/s]
# 100%|██████████| 436/436 [00:22<00:00, 19.01it/s]
# Total unique images copied: 436
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera3_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera4 selecting...
# 100%|██████████| 756/756 [00:35<00:00, 21.19it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera4_select filtering...
# 100%|██████████| 756/756 [02:53<00:00,  4.36it/s]
# 100%|██████████| 311/311 [00:15<00:00, 19.84it/s]
# Total unique images copied: 311
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera4_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera5 selecting...
# 100%|██████████| 756/756 [00:35<00:00, 21.25it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera5_select filtering...
# 100%|██████████| 756/756 [02:50<00:00,  4.43it/s]
# 100%|██████████| 440/440 [00:25<00:00, 17.35it/s]
# Total unique images copied: 440
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera5_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera6 selecting...
# 100%|██████████| 756/756 [00:43<00:00, 17.40it/s]
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera6_select filtering...
# 100%|██████████| 756/756 [02:51<00:00,  4.41it/s]
# 100%|██████████| 567/567 [00:38<00:00, 14.90it/s]
# Total unique images copied: 567
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\12-52-08_PM\cameras\camera6_filter done
#
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir\cameras\camera1 not exists
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir\cameras\camera2 not exists
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir\cameras\camera3 not exists
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir\cameras\camera4 not exists
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir\cameras\camera5 not exists
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir\cameras\camera6 not exists

# %%
def img_merge(input_dir, output_dir):
    sub_dirs = os.listdir(input_dir)
    if 'merge_dir' in sub_dirs:
        sub_dirs.remove('merge_dir')
    os.makedirs(output_dir, exist_ok=True)
    for sub_name in sub_dirs:
        sub_dir = os.path.join(input_dir, sub_name)
        if not os.path.isdir(sub_dir) or sub_name.startswith('r'):
            continue
        cam_name_list = ['camera1', 'camera2', 'camera3', 'camera4', 'camera5', 'camera6']
        for cam_name in cam_name_list:
            image_dir_src = os.path.join(sub_dir, 'cameras', cam_name+'_filter')
            if not os.path.exists(image_dir_src):
                print(f'{image_dir_src} not exists')
            else:
                img_list = os.listdir(image_dir_src)
                for img_name in tqdm(img_list):
                    img_path_src = os.path.join(image_dir_src, img_name)
                    img_path_dst = os.path.join(output_dir, cam_name+'_'+img_name)
                    shutil.copyfile(img_path_src, img_path_dst)

# %%
img_merge(root_dir, merge_dir)
# Out:
# 100%|██████████| 957/957 [00:56<00:00, 17.01it/s]
# 100%|██████████| 603/603 [00:32<00:00, 18.52it/s]
# 100%|██████████| 758/758 [00:40<00:00, 18.60it/s]
# 100%|██████████| 528/528 [00:25<00:00, 20.87it/s]
# 100%|██████████| 755/755 [00:33<00:00, 22.82it/s]
# 100%|██████████| 926/926 [01:06<00:00, 13.88it/s]
# 100%|██████████| 606/606 [00:44<00:00, 13.72it/s]
# 100%|██████████| 190/190 [00:11<00:00, 15.98it/s]
# 100%|██████████| 261/261 [00:11<00:00, 22.20it/s]
# 100%|██████████| 186/186 [00:08<00:00, 22.32it/s]
# 100%|██████████| 273/273 [00:11<00:00, 23.49it/s]
# 100%|██████████| 522/522 [00:42<00:00, 12.15it/s]
# 100%|██████████| 493/493 [00:37<00:00, 13.10it/s]
# 100%|██████████| 177/177 [00:07<00:00, 22.91it/s]
# 100%|██████████| 235/235 [00:10<00:00, 21.87it/s]
# 100%|██████████| 164/164 [00:07<00:00, 21.59it/s]
# 100%|██████████| 312/312 [00:14<00:00, 21.19it/s]
# 100%|██████████| 377/377 [00:30<00:00, 12.28it/s]
# 100%|██████████| 819/819 [01:10<00:00, 11.55it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.35it/s]
# 100%|██████████| 492/492 [00:35<00:00, 13.94it/s]
# 100%|██████████| 369/369 [00:24<00:00, 15.11it/s]
# 100%|██████████| 566/566 [00:31<00:00, 17.95it/s]
# 100%|██████████| 720/720 [01:09<00:00, 10.31it/s]
# 100%|██████████| 573/573 [00:46<00:00, 12.29it/s]
# 100%|██████████| 341/341 [00:30<00:00, 11.08it/s]
# 100%|██████████| 436/436 [00:40<00:00, 10.68it/s]
# 100%|██████████| 311/311 [00:18<00:00, 17.22it/s]
# 100%|██████████| 440/440 [00:25<00:00, 17.50it/s]
# 100%|██████████| 567/567 [00:57<00:00,  9.89it/s]

# %%
print(len(os.listdir(merge_dir)))
# Out:
# 15059

# %%
zip_folder_to_path(
    source_folder=merge_dir,
    destination_zip=os.path.join(root_dir, os.path.basename(root_dir)+'.zip')
)
# Out:
# zip '\\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir' to '\\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\task1008.zip'

# %%
zip_folder_to_path(
    source_folder=os.path.join(merge_dir+'_infer', 'labels'),
    destination_zip=os.path.join(root_dir, os.path.basename(root_dir)+'_labels.zip')
)
# Out:
# zip '\\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\merge_dir_infer\labels' to '\\158.132.186.40\isds\huilin\isds\google_drive_data\task1008\task1008_labels.zip'

# %%
file_list = os.listdir(root_dir)
new_label_zip = None
for file_name in file_list:
    if file_name.endswith('.zip') and len(file_name.split('_')) == 3:
        new_label_zip = os.path.join(root_dir, file_name)
        break

# %%
new_label_dir = os.path.join(root_dir, os.path.basename(new_label_zip).split('.')[0])
uzip_file(new_label_zip, new_label_dir)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 new_label_dir = os.path.join(root_dir, os.path.basename(new_label_zip).split('.')[0])
#       2 uzip_file(new_label_zip, new_label_dir)
#
# File c:\Users\USER\.conda\envs\common\lib\ntpath.py:216, in basename(p)
#     214 def basename(p):
#     215     """Returns the final component of a pathname"""
# --> 216     return split(p)[1]
#
# File c:\Users\USER\.conda\envs\common\lib\ntpath.py:185, in split(p)
#     180 def split(p):
#     181     """Split a pathname.
#     182
#     183     Return tuple (head, tail) where tail is everything after the final slash.
#     184     Either part may be empty."""
# --> 185     p = os.fspath(p)
#     186     seps = _get_bothseps(p)
#     187     d, p = splitdrive(p)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
full_new_label_dir = os.path.join(new_label_dir, os.path.basename(new_label_dir))
check_label_dir = os.path.join(new_label_dir, 'check_labels')
select_dir = os.path.join(root_dir, 'select')
select_label_dir = os.path.join(select_dir, 'labels')
select_image_dir = os.path.join(select_dir, 'images')
defect_list = ['deformation', 'broken', 'abandonment', 'corrosion']
att_check(full_new_label_dir, check_label_dir, reorder=False, rm_id=True)
find_defect(check_label_dir, select_label_dir, merge_dir, select_image_dir, defect_list)
# Out:
# att_check: 100%|██████████| 1005/1005 [00:14<00:00, 71.09it/s]
# change "0" 0 lines
# remove 41 id
# find_defect: 100%|██████████| 1005/1005 [00:07<00:00, 127.24it/s]
# find 46 files with defect

# %%
fused_dir = r'\\158.132.186.40\isds\huilin\isds\fused_data\task1015'
fused_label_dir = os.path.join(fused_dir, 'labels')
fused_image_dir = os.path.join(fused_dir, 'images')
copy_all(select_label_dir, fused_label_dir, select_image_dir, fused_image_dir)
# Out:
# copy_all: 100%|██████████| 46/46 [00:02<00:00, 20.34it/s]

# %%
print(f'find {len(os.listdir(select_image_dir))} in {len(os.listdir(merge_dir))}')
print(f'{select_image_dir}\n{merge_dir}')
# Out:
# find 46 in 1137
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1006\select\images
# \\158.132.186.40\isds\huilin\isds\google_drive_data\task1006\merge_dir
