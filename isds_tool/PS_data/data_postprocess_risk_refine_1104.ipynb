# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import shutil
from att_tools import extract_single_risk_keep_single
from data_vis.yolo_sta import yolo_sta

# %%
input_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4'
input_label_dir = os.path.join(input_dir, 'labels')
input_image_dir = os.path.join(input_dir, 'images')
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_sd_path = r'/localnvme/data/billboard/attribute_l2_sd.yaml'
att_sb_path = r'/localnvme/data/billboard/attribute_l2_sb.yaml'
att_sa_path = r'/localnvme/data/billboard/attribute_l2_sa.yaml'
att_sc_path = r'/localnvme/data/billboard/attribute_l2_sc.yaml'
att_paths = {
    'a':
}
single_risk_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4_single_risk1'
risk_list = ['d', 'b', 'a', 'c']

# %%
for risk in risk_list:
    extract_single_risk_keep_single(input_label_dir, single_risk_dir, risk)
# Out:
# ...
# c: 100%|██████████| 7946/7946 [00:00<00:00, 8491.45it/s]

# %%
for risk in risk_list:
    output_image_dir = os.path.join(single_risk_dir, risk, 'images')
    output_class_path = os.path.join(single_risk_dir, risk, 'class.txt')
    output_att_path = os.path.join(single_risk_dir, risk, 'attribute.yaml')
    print(f'copy {output_image_dir}')
    shutil.copytree(input_image_dir, output_image_dir)
    shutil.copytree(output_class_path, output_class_path)
# Out:
# copy /localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4_single_risk1/d/images
# copy /localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4_single_risk1/b/images
# copy /localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4_single_risk1/a/images
# copy /localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4_single_risk1/c/images

# %%
    dataset_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c6_1031_v4'
    image_dir = os.path.join(dataset_dir, 'images')
    labels_dir = os.path.join(dataset_dir, 'labels')
    # labels_dir = r'/localnvme/project/ultralytics/runs/msegment/val694/labels'
    # labels_dir = os.path.join(dataset_dir, 'val_80p_ref', 'images_infer', 'labels')
    # labels_dir = os.path.join(dataset_dir, 'labels_refine')
    image_vis_dir = os.path.join(dataset_dir, 'result_analysis', 'image_vis')
    json_dir = os.path.join(dataset_dir, 'jsons')
    labels_sta_dir = os.path.join(dataset_dir, 'labels_sta')
    image_crop_dir = os.path.join(dataset_dir, 'result_analysis', 'all_gt')
    # image_crop_dir = os.path.join(dataset_dir, 'result_analysis', 'val694', 'all')
    class_file = os.path.join(dataset_dir, 'class.txt')
    attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
    ref_txt = os.path.join(dataset_dir, "val_test.txt")
    yolo_sta(
        # img_dir=os.path.join(dataset_dir, "images"),
        gt_dir=labels_dir,
        result_dir=labels_sta_dir,
        class_path=class_file,
        attribute_path=attribute_file,
        ref_txt=ref_txt,
        seg=True,
    )
