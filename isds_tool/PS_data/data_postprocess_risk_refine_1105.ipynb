# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import shutil
from att_tools import extract_single_risk_keep_single, risk_refine_single, risk_change, copy_files_list, remove_repeated, pred_check_iou, pred2label, labels_merge
from yolo_tools import copy_split, copy_all, data_tf_pipline_new
from data_vis.yolo_sta import yolo_sta
from yolo_mask_crop import myolo_crop

# %%
# create label_v7, label_v8

# %%
input_dir = r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1030'
class_c6_path = r'/localnvme/data/billboard/class_c6.txt'
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_l3_path = r'/localnvme/data/billboard/attribute.yaml'
att_l2_path = r'/localnvme/data/billboard/attribute_l2.yaml'
input_train_test_path = os.path.join(input_dir, 'train_test.txt')
input_val_test_path = os.path.join(input_dir, 'val_test.txt')
input_train_80p_path = os.path.join(input_dir, 'train_80p_ref.txt')
input_val_80p_path = os.path.join(input_dir, 'val_80p_ref.txt')
input_all_path = os.path.join(input_dir, 'all.txt')
input_all_test_path = os.path.join(input_dir, 'all_test.txt')
input_image_dir = os.path.join(input_dir, 'images')
input_label_v5_dir = os.path.join(input_dir, 'labels_v5')
input_label_v6_dir = os.path.join(input_dir, 'labels_v6')
output_label_v7_dir = os.path.join(input_dir, 'labels_v7')
output_label_v8_dir = os.path.join(input_dir, 'labels_v8')
output_label_v9_dir = os.path.join(input_dir, 'labels_v9')
input_label_v7_dir = output_label_v7_dir
input_label_v8_dir = output_label_v8_dir
input_label_v9_dir = output_label_v9_dir

datav5_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v5'
datav6_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v6'
datav7_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v7'
datav8_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v8'
datav9_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v9'

# %%
risk_change(input_label_v5_dir, output_label_v7_dir, src_risk='a-h', dst_risk='b-h')

# %%
risk_change(input_label_v6_dir, output_label_v8_dir, src_risk='a-h', dst_risk='b-h')

# %%
copy_all(
    input_label_v7_dir,
    os.path.join(datav7_dir, 'labels'),
    input_image_dir,
    os.path.join(datav7_dir, 'images'),
)
# Out:
# copy_all: 100%|██████████| 7946/7946 [00:19<00:00, 415.23it/s]

# %%
copy_all(
    input_label_v8_dir,
    os.path.join(datav8_dir, 'labels'),
    input_image_dir,
    os.path.join(datav8_dir, 'images'),
)
# Out:
# copy_all: 100%|██████████| 7946/7946 [00:12<00:00, 659.89it/s]

# %%
output_dir = datav7_dir
shutil.copy(class_c6_path, os.path.join(output_dir, 'class.txt'))
shutil.copy(att_l3_path, os.path.join(output_dir, 'attribute.yaml'))
# Out:
# '/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v7/attribute.yaml'

# %%
output_dir = datav7_dir
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path)
copy_split(input_val_test_path, output_val_test_path)
copy_split(input_train_80p_path, output_train_80p_path)
copy_split(input_val_80p_path, output_val_80p_path)
copy_split(input_all_path, output_all_path)
copy_split(input_all_test_path, output_all_test_path)
# Out:
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records

# %%
output_dir = datav8_dir
shutil.copy(class_c6_path, os.path.join(output_dir, 'class.txt'))
shutil.copy(att_l3_path, os.path.join(output_dir, 'attribute.yaml'))
# Out:
# '/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v8/attribute.yaml'

# %%
output_dir = datav8_dir
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path)
copy_split(input_val_test_path, output_val_test_path)
copy_split(input_train_80p_path, output_train_80p_path)
copy_split(input_val_80p_path, output_val_80p_path)
copy_split(input_all_path, output_all_path)
copy_split(input_all_test_path, output_all_test_path)
# Out:
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records

# %%
data_tf_pipline_new(datav7_dir, copy_list=['mseg_c5_l2'])
# Out:
# ...
# risk to l2: 100%|██████████| 7946/7946 [00:14<00:00, 554.17it/s]

# %%
data_tf_pipline_new(datav8_dir, copy_list=['mseg_c5_l2'])
# Out:
# ...
# risk to l2: 100%|██████████| 7946/7946 [00:16<00:00, 493.21it/s]

# %%
output_dir = datav7_dir.replace('mseg_c6', 'mseg_c5_l2')
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path, abs_path=True)
copy_split(input_val_test_path, output_val_test_path, abs_path=True)
copy_split(input_train_80p_path, output_train_80p_path, abs_path=True)
copy_split(input_val_80p_path, output_val_80p_path, abs_path=True)
copy_split(input_all_path, output_all_path, abs_path=True)
copy_split(input_all_test_path, output_all_test_path, abs_path=True)
# Out:
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records

# %%
output_dir = datav8_dir.replace('mseg_c6', 'mseg_c5_l2')
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path, abs_path=True)
copy_split(input_val_test_path, output_val_test_path, abs_path=True)
copy_split(input_train_80p_path, output_train_80p_path, abs_path=True)
copy_split(input_val_80p_path, output_val_80p_path, abs_path=True)
copy_split(input_all_path, output_all_path, abs_path=True)
copy_split(input_all_test_path, output_all_test_path, abs_path=True)
# Out:
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records

# %%
dataset_dir = datav7_dir
image_dir = os.path.join(dataset_dir, 'images')
labels_dir = os.path.join(dataset_dir, 'labels')
labels_sta_dir = os.path.join(dataset_dir, 'label_analysis', 'labels_sta')
image_crop_dir = os.path.join(dataset_dir, 'label_analysis', 'all_gt')
class_file = os.path.join(dataset_dir, 'class.txt')
attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
yolo_sta(
    gt_dir=labels_dir,
    result_dir=labels_sta_dir,
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)
# Out:
# label read: 100%|██████████| 7946/7946 [00:33<00:00, 240.58it/s]
# get 7946 labels, merging...
# /localnvme/project/dataset_tools/data_vis/yolo_sta.py:303: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dfs = pd.concat(dfs)
# merging finish, get 57923 labels!
# csv save to /localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v7/label_analysis/labels_sta/sta_attribute.csv
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 总box数: 57923; 有缺陷的box数: 3844; 没有缺陷的box数: 54079
# 总image数: 7843; 有缺陷的image数: 2739; 没有缺陷的image数: 5104
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...

# %%
dataset_dir = datav8_dir
image_dir = os.path.join(dataset_dir, 'images')
labels_dir = os.path.join(dataset_dir, 'labels')
labels_sta_dir = os.path.join(dataset_dir, 'label_analysis', 'labels_sta')
image_crop_dir = os.path.join(dataset_dir, 'label_analysis', 'all_gt')
class_file = os.path.join(dataset_dir, 'class.txt')
attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
yolo_sta(
    gt_dir=labels_dir,
    result_dir=labels_sta_dir,
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)
# Out:
# label read: 100%|██████████| 7946/7946 [00:32<00:00, 244.31it/s]
# get 7946 labels, merging...
# /localnvme/project/dataset_tools/data_vis/yolo_sta.py:303: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dfs = pd.concat(dfs)
# merging finish, get 57923 labels!
# csv save to /localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v8/label_analysis/labels_sta/sta_attribute.csv
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 总box数: 57923; 有缺陷的box数: 3662; 没有缺陷的box数: 54261
# 总image数: 7843; 有缺陷的image数: 2608; 没有缺陷的image数: 5235
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...

# %%
dataset_dir = datav5_dir
image_dir = os.path.join(dataset_dir, 'images')
labels_dir = os.path.join(dataset_dir, 'labels')
labels_sta_dir = os.path.join(dataset_dir, 'label_analysis', 'labels_sta')
image_crop_dir = os.path.join(dataset_dir, 'label_analysis', 'all_gt')
class_file = os.path.join(dataset_dir, 'class.txt')
attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
yolo_sta(
    gt_dir=labels_dir,
    result_dir=labels_sta_dir,
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)
# Out:
# label read: 100%|██████████| 7946/7946 [00:31<00:00, 248.71it/s]
# get 7946 labels, merging...
# /localnvme/project/dataset_tools/data_vis/yolo_sta.py:303: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dfs = pd.concat(dfs)
# merging finish, get 57923 labels!
# csv save to /localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v5/label_analysis/labels_sta/sta_attribute.csv
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 总box数: 57923; 有缺陷的box数: 3844; 没有缺陷的box数: 54079
# 总image数: 7843; 有缺陷的image数: 2739; 没有缺陷的image数: 5104
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...

# %%
dataset_dir = datav6_dir
image_dir = os.path.join(dataset_dir, 'images')
labels_dir = os.path.join(dataset_dir, 'labels')
labels_sta_dir = os.path.join(dataset_dir, 'label_analysis', 'labels_sta')
image_crop_dir = os.path.join(dataset_dir, 'label_analysis', 'all_gt')
class_file = os.path.join(dataset_dir, 'class.txt')
attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
yolo_sta(
    gt_dir=labels_dir,
    result_dir=labels_sta_dir,
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)
# Out:
# label read: 100%|██████████| 7946/7946 [00:32<00:00, 247.16it/s]
# get 7946 labels, merging...
# /localnvme/project/dataset_tools/data_vis/yolo_sta.py:303: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dfs = pd.concat(dfs)
# merging finish, get 57923 labels!
# csv save to /localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1104_v6/label_analysis/labels_sta/sta_attribute.csv
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 总box数: 57923; 有缺陷的box数: 3662; 没有缺陷的box数: 54261
# 总image数: 7843; 有缺陷的image数: 2608; 没有缺陷的image数: 5235
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...

# %%
# create label_v9, merge pred(val694) segmentation results

# %%
ref_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep'
risk_list = ['abandonment', 'broken', 'corrosion', 'deformation']

# %%
for risk in risk_list:
    pred_high_label_bg = os.path.join(ref_dir, 'pred_high_label_background', f'risk_{risk}_pred_high_label_background')
    pred_medium_label_bg = os.path.join(ref_dir, 'pred_medium_label_background', f'risk_{risk}_pred_medium_label_background')
    pred_no_label_bg = os.path.join(ref_dir, 'pred_no_label_background', f'risk_{risk}_pred_no_label_background')
    print(f'{os.path.basename(pred_high_label_bg)} {os.path.exists(pred_high_label_bg)} {len(os.listdir(pred_high_label_bg))}')
    print(f'{os.path.basename(pred_medium_label_bg)} {os.path.exists(pred_medium_label_bg)} {len(os.listdir(pred_medium_label_bg))}')
    print(f'{os.path.basename(pred_no_label_bg)} {os.path.exists(pred_no_label_bg)} {len(os.listdir(pred_no_label_bg))}')
# Out:
# risk_abandonment_pred_high_label_background True 2
# risk_abandonment_pred_medium_label_background True 94
# risk_abandonment_pred_no_label_background True 8656
# risk_broken_pred_high_label_background True 0
# risk_broken_pred_medium_label_background True 16
# risk_broken_pred_no_label_background True 8830
# risk_corrosion_pred_high_label_background True 136
# risk_corrosion_pred_medium_label_background True 30
# risk_corrosion_pred_no_label_background True 8446
# risk_deformation_pred_high_label_background True 0
# risk_deformation_pred_medium_label_background True 8
# risk_deformation_pred_no_label_background True 8756

# %%
pred_no_label_background_all_without_risk = os.path.join(ref_dir, 'pred_no_label_background', 'all_without_risk')
os.makedirs(pred_no_label_background_all_without_risk, exist_ok=True)
for risk in risk_list:
    pred_no_label_bg = os.path.join(ref_dir, 'pred_no_label_background', f'risk_{risk}_pred_no_label_background')
    copy_files_list(pred_no_label_bg, pred_no_label_background_all_without_risk)
# Out:
# copy risk_abandonment_pred_no_label_background -> all_without_risk: 100%|██████████| 8656/8656 [00:02<00:00, 2963.17it/s]
# copy risk_broken_pred_no_label_background -> all_without_risk: 100%|██████████| 8830/8830 [00:05<00:00, 1608.32it/s]
# copy risk_corrosion_pred_no_label_background -> all_without_risk: 100%|██████████| 8446/8446 [00:04<00:00, 1944.78it/s]
# copy risk_deformation_pred_no_label_background -> all_without_risk: 100%|██████████| 8756/8756 [00:03<00:00, 2470.01it/s]

# %%
pred_no_label_background_all_with_risk = os.path.join(ref_dir, 'pred_no_label_background', 'all_with_risk')
os.makedirs(pred_no_label_background_all_with_risk, exist_ok=True)
for risk in risk_list:
    pred_high_label_bg = os.path.join(ref_dir, 'pred_high_label_background', f'risk_{risk}_pred_high_label_background')
    pred_medium_label_bg = os.path.join(ref_dir, 'pred_medium_label_background', f'risk_{risk}_pred_medium_label_background')
    copy_files_list(pred_high_label_bg, pred_no_label_background_all_with_risk)
    copy_files_list(pred_medium_label_bg, pred_no_label_background_all_with_risk)
# Out:
# copy risk_abandonment_pred_high_label_background -> all_with_risk: 100%|██████████| 2/2 [00:00<00:00, 996.63it/s]
# copy risk_abandonment_pred_medium_label_background -> all_with_risk: 100%|██████████| 94/94 [00:00<00:00, 4657.75it/s]
# copy risk_broken_pred_high_label_background -> all_with_risk: 0it [00:00, ?it/s]
# copy risk_broken_pred_medium_label_background -> all_with_risk: 100%|██████████| 16/16 [00:00<00:00, 7640.77it/s]
# copy risk_corrosion_pred_high_label_background -> all_with_risk: 100%|██████████| 136/136 [00:00<00:00, 1095.76it/s]
# copy risk_corrosion_pred_medium_label_background -> all_with_risk: 100%|██████████| 30/30 [00:00<00:00, 3711.01it/s]
# copy risk_deformation_pred_high_label_background -> all_with_risk: 0it [00:00, ?it/s]
# copy risk_deformation_pred_medium_label_background -> all_with_risk: 100%|██████████| 8/8 [00:00<00:00, 1632.34it/s]

# %%
remove_repeated(pred_no_label_background_all_without_risk, pred_no_label_background_all_with_risk)
# Out:
# 100%|██████████| 280/280 [00:00<00:00, 2477.76it/s]

# %%
# mannual check

# %%
# pred_check_iou(
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/labels',
#     r'/localnvme/project/ultralytics/runs/msegment/val694/labels',
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_without_risk',
#     # r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_with_risk',
#     attributes=r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/attribute.yaml',
# )

# remove_by_list(
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_without_risk_iou_check.csv',
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_without_risk',
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_without_risk_iou_check',
# )
# remove_by_list(
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_with_risk_iou_check.csv',
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_with_risk',
#     r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/all_with_risk_iou_check',
# )

# %%
data1105_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/result_analysis/keep/pred_no_label_background/merge_1105'
data1105_dir_all = os.path.join(data1105_dir, 'all')
data1105_dir_with_defect = os.path.join(data1105_dir, 'all_with_risk')
data1105_dir_with_defect_pending = os.path.join(data1105_dir, 'all_with_risk_pending')
data1105_dir_without_defect = os.path.join(data1105_dir, 'all_without_risk')
data1105_label_dir = data1105_dir+'_labels'

# %%
copy_files_list(data1105_dir_with_defect, data1105_dir_all)
copy_files_list(data1105_dir_with_defect_pending, data1105_dir_all)
copy_files_list(data1105_dir_without_defect, data1105_dir_all)
# Out:
# copy all_with_risk -> all: 100%|██████████| 206/206 [00:00<00:00, 8774.34it/s]
# copy 206 to all, get 206
# copy all_with_risk_pending -> all: 100%|██████████| 248/248 [00:00<00:00, 3132.68it/s]
# copy 248 to all, get 454
# copy all_without_risk -> all: 100%|██████████| 3453/3453 [00:00<00:00, 6352.79it/s]
# copy 3453 to all, get 3907

# %%
pred2label(
    r'/localnvme/project/ultralytics/runs/msegment/val694/labels',
    data1105_dir_all,
    data1105_label_dir,
    attributes=r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine/attribute.yaml',
)
# Out:
# load pred_obj: 100%|██████████| 3907/3907 [00:00<00:00, 110472.41it/s]
# load 2753/3907 records,
# load pred_list: 100%|██████████| 7805/7805 [00:00<00:00, 24371.33it/s]
# change 2753/3907 records,

# %%
labels_merge(output_label_v7_dir, data1105_label_dir, output_label_v9_dir)
# Out:
# merge: 100%|██████████| 7946/7946 [00:00<00:00, 13954.65it/s]

# %%
copy_all(
    input_label_v9_dir,
    os.path.join(datav9_dir, 'labels'),
    input_image_dir,
    os.path.join(datav9_dir, 'images'),
)
# Out:
# copy_all: 100%|██████████| 7946/7946 [00:22<00:00, 345.92it/s]

# %%
data_tf_pipline_new(datav9_dir, copy_list=['seg_c5'])
# Out:
# ...
# mseg2seg:: 100%|██████████| 7946/7946 [00:08<00:00, 946.46it/s]

# %%
base_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1029_abandonment_refine'
image_dir = os.path.join(base_dir, 'images')
label_dir_root = os.path.join(base_dir, 'result_analysis', 'keep', 'pred_no_label_background')
label_dir = os.path.join(label_dir_root, 'merge_1105_labels')
image_crop_dir = os.path.join(label_dir_root, 'merge_1105_labels_crop')
attribute_file = os.path.join(base_dir, 'attribute.yaml')
class_file = os.path.join(base_dir, 'class.txt')
myolo_crop(image_dir, label_dir, image_crop_dir, class_file,
           attribute_file=attribute_file, seg=True, annotation=False,
           save_method='attribute', only_defect=True, with_boundary=False,
           crop_method='with_background_box_shape')
# Out:
# mask cropping :  75%|███████▌  | 5969/7946 [01:59<00:39, 49.76it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 8
#       6 attribute_file = os.path.join(base_dir, 'attribute.yaml')
#       7 class_file = os.path.join(base_dir, 'class.txt')
# ----> 8 myolo_crop(image_dir, label_dir, image_crop_dir, class_file,
#       9            attribute_file=attribute_file, seg=True, annotation=False,
#      10            save_method='attribute', only_defect=True, with_boundary=False,
#      11            crop_method='with_background_box_shape')
#
# File /localnvme/project/dataset_tools/isds_tool/PS_data/yolo_mask_crop.py:263, in myolo_crop(image_dir, label_dir, crop_dir, class_file, attribute_file, seg, annotation, ref_list, only_defect, save_method, crop_method, with_boundary, with_conf)
#     261 if not os.path.exists(label_path):
#     262     continue
# ...

# %%
for risk in risk_list:
    dataset_dir = os.path.join(single_risk_dir, risk)
    image_dir = os.path.join(dataset_dir, 'images')
    labels_dir = os.path.join(dataset_dir, 'labels')
    labels_sta_dir = os.path.join(dataset_dir, 'label_analysis', 'labels_sta')
    image_crop_dir = os.path.join(dataset_dir, 'label_analysis', 'all_gt')
    class_file = os.path.join(dataset_dir, 'class.txt')
    attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
    yolo_sta(
        gt_dir=labels_dir,
        result_dir=labels_sta_dir,
        class_path=class_file,
        attribute_path=attribute_file,
        seg=True,
    )

# %%
input_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4'
input_label_dir = os.path.join(input_dir, 'labels')
input_image_dir = os.path.join(input_dir, 'images')
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_sd_path = r'/localnvme/data/billboard/attribute_l2_sd.yaml'
att_sb_path = r'/localnvme/data/billboard/attribute_l2_sb.yaml'
att_sa_path = r'/localnvme/data/billboard/attribute_l2_sa.yaml'
att_sc_path = r'/localnvme/data/billboard/attribute_l2_sc.yaml'
att_paths = {
    'a': att_sa_path,
    'b': att_sb_path,
    'c': att_sc_path,
    'd': att_sd_path,
}
single_risk_dir = r'/localnvme/data/billboard/fused_data/data7961_mseg_c5_l2_1031_v4_single_risk1'
risk_list = ['d', 'b', 'a', 'c']

# %%
for risk in risk_list:
    extract_single_risk_keep_single(input_label_dir, single_risk_dir, risk)

# %%
for risk in risk_list:
    output_image_dir = os.path.join(single_risk_dir, risk, 'images')
    print(f'copy {output_image_dir}')
    shutil.copytree(input_image_dir, output_image_dir)

# %%
for risk in risk_list:
    output_class_path = os.path.join(single_risk_dir, risk, 'class.txt')
    output_att_path = os.path.join(single_risk_dir, risk, 'attribute.yaml')
    print(f'copy {output_class_path}; {output_att_path}')
    shutil.copy(class_c5_path, output_class_path)
    shutil.copy(att_paths[risk], output_att_path)

# %%
for risk in risk_list:
    input_train_test_path = os.path.join(input_dir, 'train_test.txt')
    input_val_test_path = os.path.join(input_dir, 'val_test.txt')
    input_train_80p_path = os.path.join(input_dir, 'train_80p_ref.txt')
    input_val_80p_path = os.path.join(input_dir, 'val_80p_ref.txt')
    input_all_path = os.path.join(input_dir, 'all.txt')
    input_all_src_path = os.path.join(input_dir, 'all_src.txt')
    output_train_test_path = os.path.join(single_risk_dir, risk, 'train_test.txt')
    output_val_test_path = os.path.join(single_risk_dir, risk, 'val_test.txt')
    output_train_80p_path = os.path.join(single_risk_dir, risk, 'train_80p_ref.txt')
    output_val_80p_path = os.path.join(single_risk_dir, risk, 'val_80p_ref.txt')
    output_all_path = os.path.join(single_risk_dir, risk, 'all.txt')
    output_all_src_path = os.path.join(single_risk_dir, risk, 'all_src.txt')

    copy_split(input_train_test_path, output_train_test_path)
    copy_split(input_val_test_path, output_val_test_path)
    copy_split(input_train_80p_path, output_train_80p_path)
    copy_split(input_val_80p_path, output_val_80p_path)
    copy_split(input_all_path, output_all_path)
    copy_split(input_all_src_path, output_all_src_path)
    print()

# %%
for risk in risk_list:
    dataset_dir = os.path.join(single_risk_dir, risk)
    image_dir = os.path.join(dataset_dir, 'images')
    labels_dir = os.path.join(dataset_dir, 'labels')
    labels_sta_dir = os.path.join(dataset_dir, 'label_analysis', 'labels_sta')
    image_crop_dir = os.path.join(dataset_dir, 'label_analysis', 'all_gt')
    class_file = os.path.join(dataset_dir, 'class.txt')
    attribute_file = os.path.join(dataset_dir, 'attribute.yaml')
    yolo_sta(
        gt_dir=labels_dir,
        result_dir=labels_sta_dir,
        class_path=class_file,
        attribute_path=attribute_file,
        seg=True,
    )
