# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from att_tools import vis_matched_result
from yolo_tools import select_val

# %%
base_dir = r'/localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1106_v12'
image_dir = os.path.join(base_dir, 'images')
label_dir = os.path.join(base_dir, 'labels')
val_test_dir = os.path.join(base_dir, 'val_test')
image_test_dir = os.path.join(val_test_dir, 'images')
label_test_dir = os.path.join(val_test_dir, 'labels')
result_analysis_dir = os.path.join(base_dir, 'result_analysis')
vis_dir = os.path.join(result_analysis_dir, 'vis')
class_path = os.path.join(base_dir, 'class.txt')
att_path = os.path.join(base_dir, 'attribute.yaml')
val_test_path = os.path.join(base_dir, 'val_test.txt')
pred_dir = r'/localnvme/project/ultralytics/runs/msegment/val727/labels'

# %%
select_val(base_dir, val_test_path)
# Out:
# select /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1106_v12 by /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1106_v12/val_test.txt
# 100%|██████████| 80/80 [00:00<00:00, 364.11it/s]
# select finish!

# %%
vis_matched_result(
    image_test_dir,
    label_test_dir,
    pred_dir,
    vis_dir,
    class_path,
    att_path,
    with_conf=True,
    iou_thr=0.3,
    conf_threshold=0.4,
    defect_conf_threshold=0.4,
    filter_small=0.05,
    save_method='attribute',
    # crop_method='with_background_box_shape',
    crop_method='with_background_image_shape',
)
# Out:
# remove_conf: 100%|██████████| 80/80 [00:00<00:00, 842.03it/s]
# mask cropping : 100%|██████████| 80/80 [22:14<00:00, 16.68s/it]
# 100%|██████████| 738/738 [00:00<00:00, 192883.62it/s]
# mask cropping : 100%|██████████| 80/80 [6:55:56<00:00, 311.96s/it]
# 100%|██████████| 7861/7861 [00:00<00:00, 212816.35it/s]
# read and process label: 100%|██████████| 80/80 [10:13<00:00,  7.66s/it]
