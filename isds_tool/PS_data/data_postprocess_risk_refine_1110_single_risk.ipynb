# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import shutil
from att_tools import extract_single_risk_keep_single
from yolo_tools import copy_all,copy_split,data_tf_pipline_new

# %%
base_dir = r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1030'
image_dir = os.path.join(base_dir, 'images')
label_dir = os.path.join(base_dir, 'labels')
attribute_file = os.path.join(base_dir, 'attribute.yaml')
class_file = os.path.join(base_dir, 'class.txt')
class_c6_path = r'/localnvme/data/billboard/class_c6.txt'
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_l3_path = r'/localnvme/data/billboard/attribute.yaml'
att_l2_path = r'/localnvme/data/billboard/attribute_l2.yaml'
att_l2_sa_path = r'/localnvme/data/billboard/attribute_l2_sa.yaml'
att_l2_sb_path = r'/localnvme/data/billboard/attribute_l2_sb.yaml'
att_l2_sc_path = r'/localnvme/data/billboard/attribute_l2_sc.yaml'
att_l2_sd_path = r'/localnvme/data/billboard/attribute_l2_sd.yaml'
input_dir = base_dir
input_train_test_path = os.path.join(input_dir, 'train_test.txt')
input_val_test_path = os.path.join(input_dir, 'val_test.txt')
input_train_80p_path = os.path.join(input_dir, 'train_80p_ref.txt')
input_val_80p_path = os.path.join(input_dir, 'val_80p_ref.txt')
input_all_path = os.path.join(input_dir, 'all.txt')
input_all_test_path = os.path.join(input_dir, 'all_test.txt')
label_v13_dir = os.path.join(base_dir, 'labels_v13')
datav13_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1110_v13'
datav13_dir_image = os.path.join(datav13_dir, 'images')
datav13_dir_label = os.path.join(datav13_dir, 'labels')

datav13_c5l2_dir =  r'/localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13'
datav13_c5l2_dir_image = os.path.join(datav13_c5l2_dir, 'images')
datav13_c5l2_dir_label = os.path.join(datav13_c5l2_dir, 'labels')

# %%
copy_all(
    label_v13_dir,
    datav13_dir_label,
    image_dir,
    datav13_dir_image,
)
# Out:
# copy_all: 100%|██████████| 7946/7946 [00:26<00:00, 303.07it/s]

# %%
output_dir = datav13_dir
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path)
copy_split(input_val_test_path, output_val_test_path)
copy_split(input_train_80p_path, output_train_80p_path)
copy_split(input_val_80p_path, output_val_80p_path)
copy_split(input_all_path, output_all_path)
copy_split(input_all_test_path, output_all_test_path)

shutil.copy(class_c6_path, os.path.join(output_dir, 'class.txt'))
shutil.copy(att_l3_path, os.path.join(output_dir, 'attribute.yaml'))
# Out:
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records
# '/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1110_v13/attribute.yaml'

# %%
data_tf_pipline_new(datav13_dir, copy_list=['mseg_c5_l2', 'seg_c5'])
# Out:
# change to c5:: 100%|██████████| 7946/7946 [00:16<00:00, 491.90it/s]
# risk to l2: 100%|██████████| 7946/7946 [00:21<00:00, 372.37it/s]
# mseg2seg:: 100%|██████████| 7946/7946 [00:17<00:00, 449.43it/s]

# %%
output_dir = datav13_dir.replace('mseg_c6', 'mseg_c5_l2')
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path, abs_path=True)
copy_split(input_val_test_path, output_val_test_path, abs_path=True)
copy_split(input_train_80p_path, output_train_80p_path, abs_path=True)
copy_split(input_val_80p_path, output_val_80p_path, abs_path=True)
copy_split(input_all_path, output_all_path, abs_path=True)
copy_split(input_all_test_path, output_all_test_path, abs_path=True)
# Out:
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records

# %%
# single risk

# %%
single_risk_dir = datav13_c5l2_dir + '_single_risk'
risk_list = ['d', 'b', 'a', 'c']

# %%
for risk in risk_list:
    extract_single_risk_keep_single(datav13_c5l2_dir_label, single_risk_dir, risk)
# Out:
# d: 100%|██████████| 7946/7946 [00:01<00:00, 5471.49it/s]
# b: 100%|██████████| 7946/7946 [00:01<00:00, 5618.00it/s]
# a: 100%|██████████| 7946/7946 [00:01<00:00, 5880.86it/s]
# c: 100%|██████████| 7946/7946 [00:01<00:00, 5771.88it/s]

# %%
for risk in risk_list:
    output_image_dir = os.path.join(single_risk_dir, risk, 'images')
    print(f'copy {output_image_dir}')
    shutil.copytree(datav13_dir_image, output_image_dir)
# Out:
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/d/images
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[27], line 4
#       2 output_image_dir = os.path.join(single_risk_dir, risk, 'images')
#       3 print(f'copy {output_image_dir}')
# ----> 4 shutil.copytree(datav13_dir_image, output_image_dir)
#
# File ~/.conda/envs/ultralytics/lib/python3.12/shutil.py:600, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598 with os.scandir(src) as itr:
#     599     entries = list(itr)
# --> 600 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                  ignore=ignore, copy_function=copy_function,
#     602                  ignore_dangling_symlinks=ignore_dangling_symlinks,
#     603                  dirs_exist_ok=dirs_exist_ok)
#
# File ~/.conda/envs/ultralytics/lib/python3.12/shutil.py:498, in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     495 else:
#     496     ignored_names = ()
# --> 498 os.makedirs(dst, exist_ok=dirs_exist_ok)
#     499 errors = []
#     500 use_srcentry = copy_function is copy2 or copy_function is copy
#
# File ~/.conda/envs/ultralytics/lib/python3.12/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '/localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/d/images'

# %%
for risk in risk_list:
    class_path = os.path.join(single_risk_dir, risk, 'class.txt')
    print(f'copy {class_path}')
    shutil.copy(class_c5_path, class_path)
    att_path = os.path.join(single_risk_dir, risk, 'attribute.yaml')
    print(f'copy {att_path}')
    if risk == 'a':
        shutil.copy(att_l2_sa_path, att_path)
    elif risk == 'b':
        shutil.copy(att_l2_sb_path, att_path)
    elif risk == 'c':
        shutil.copy(att_l2_sc_path, att_path)
    elif risk == 'd':
        shutil.copy(att_l2_sd_path, att_path)
    else:
        print('error')

    output_dir = os.path.join(single_risk_dir, risk)
    output_train_test_path = os.path.join(output_dir, 'train_test.txt')
    output_val_test_path = os.path.join(output_dir, 'val_test.txt')
    output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
    output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
    output_all_path = os.path.join(output_dir, 'all.txt')
    output_all_test_path = os.path.join(output_dir, 'all_test.txt')

    copy_split(input_train_test_path, output_train_test_path, abs_path=True)
    copy_split(input_val_test_path, output_val_test_path, abs_path=True)
    copy_split(input_train_80p_path, output_train_80p_path, abs_path=True)
    copy_split(input_val_80p_path, output_val_80p_path, abs_path=True)
    copy_split(input_all_path, output_all_path, abs_path=True)
    copy_split(input_all_test_path, output_all_test_path, abs_path=True)
# Out:
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/d/class.txt
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/d/attribute.yaml
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/b/class.txt
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/b/attribute.yaml
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/a/class.txt
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/a/attribute.yaml
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/c/class.txt
# copy /localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1110_v13_single_risk/c/attribute.yaml
# copy train_test.txt, 7872 records
# copy val_test.txt, 80 records
# copy train_80p_ref.txt, 7606 records
# copy val_80p_ref.txt, 266 records
# copy all.txt, 7872 records
# copy all_test.txt, 7952 records
