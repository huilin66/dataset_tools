# %%
# %load_ext autoreload
# %autoreload 2

# %%
# category check

# %%
import os
import shutil
from data_vis.yolo_sta import yolo_sta
from att_tools import category_update_by_ref
from yolo_tools import copy_all, copy_split, data_tf_pipline_new

# %%
base_dir = r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1030'
image_dir = os.path.join(base_dir, 'images')
label_dir = os.path.join(base_dir, 'labels_v10')
label_ana_dir = os.path.join(base_dir, 'labels_analysis')
label_sta_dir = os.path.join(label_ana_dir, 'gt_sta_v10')
image_crop_dir = os.path.join(label_ana_dir, 'all_gt_v10')
attribute_file = os.path.join(base_dir, 'attribute.yaml')
class_file = os.path.join(base_dir, 'class.txt')
class_c6_path = r'/localnvme/data/billboard/class_c6.txt'
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_l3_path = r'/localnvme/data/billboard/attribute.yaml'
att_l2_path = r'/localnvme/data/billboard/attribute_l2.yaml'
input_dir = base_dir
input_train_test_path = os.path.join(input_dir, 'train_test.txt')
input_val_test_path = os.path.join(input_dir, 'val_test.txt')
input_train_80p_path = os.path.join(input_dir, 'train_80p_ref.txt')
input_val_80p_path = os.path.join(input_dir, 'val_80p_ref.txt')
input_all_path = os.path.join(input_dir, 'all.txt')
input_all_test_path = os.path.join(input_dir, 'all_test.txt')
label_v10_dir = os.path.join(base_dir, 'labels_v10')
label_v14_dir = os.path.join(base_dir, 'labels_v14')
check_dir = r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1030/labels_analysis/all_gt_v10_category_corrrect'
datav14_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1106_v14'

# %%
category_update_by_ref(label_v10_dir,label_v14_dir,check_dir,class_file)

# %%
yolo_sta(
    gt_dir=label_v10_dir,
    result_dir=label_v10_dir+'_sta',
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)

# %%
yolo_sta(
    gt_dir=label_v14_dir,
    result_dir=label_v14_dir+'_sta',
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)

# %%
copy_all(
    label_v14_dir,
    os.path.join(datav14_dir, 'labels'),
    image_dir,
    os.path.join(datav14_dir, 'images'),
)

# %%
output_dir = datav14_dir
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path)
copy_split(input_val_test_path, output_val_test_path)
copy_split(input_train_80p_path, output_train_80p_path)
copy_split(input_val_80p_path, output_val_80p_path)
copy_split(input_all_path, output_all_path)
copy_split(input_all_test_path, output_all_test_path)

shutil.copy(class_c6_path, os.path.join(output_dir, 'class.txt'))
shutil.copy(att_l3_path, os.path.join(output_dir, 'attribute.yaml'))

# %%
data_tf_pipline_new(datav14_dir, copy_list=['mseg_c5_l2'])

# %%
output_dir = datav14_dir.replace('mseg_c6', 'mseg_c5_l2')
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path, abs_path=True)
copy_split(input_val_test_path, output_val_test_path, abs_path=True)
copy_split(input_train_80p_path, output_train_80p_path, abs_path=True)
copy_split(input_val_80p_path, output_val_80p_path, abs_path=True)
copy_split(input_all_path, output_all_path, abs_path=True)
copy_split(input_all_test_path, output_all_test_path, abs_path=True)

# %%
# find empty

# %%
from yolo_tools import find_empty_file, copy_ref_csv

# %%
label_v14_empty_dir = os.path.join(label_ana_dir, 'label_v14_empty')
label_v14_empty_path = os.path.join(label_ana_dir, 'label_v14_empty.csv')

# %%
find_empty_file(label_v14_dir, label_v14_empty_path, att_l2_path)

# %%
copy_ref_csv(image_dir, label_v14_empty_dir, label_v14_empty_path)

# %%
# update broken

# %%
import os
import shutil
from data_vis.yolo_sta import yolo_sta
from att_tools import update_risk_by_ref
from yolo_tools import copy_all, copy_split, data_tf_pipline_new

# %%
base_dir = r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1030'
image_dir = os.path.join(base_dir, 'images')
label_dir = os.path.join(base_dir, 'labels_v10')
label_ana_dir = os.path.join(base_dir, 'labels_analysis')
attribute_file = os.path.join(base_dir, 'attribute.yaml')
class_file = os.path.join(base_dir, 'class.txt')
class_c6_path = r'/localnvme/data/billboard/class_c6.txt'
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_l3_path = r'/localnvme/data/billboard/attribute.yaml'
att_l2_path = r'/localnvme/data/billboard/attribute_l2.yaml'
input_dir = base_dir
input_train_test_path = os.path.join(input_dir, 'train_test.txt')
input_val_test_path = os.path.join(input_dir, 'val_test.txt')
input_train_80p_path = os.path.join(input_dir, 'train_80p_ref.txt')
input_val_80p_path = os.path.join(input_dir, 'val_80p_ref.txt')
input_all_path = os.path.join(input_dir, 'all.txt')
input_all_test_path = os.path.join(input_dir, 'all_test.txt')
label_v14_dir = os.path.join(base_dir, 'labels_v14')
label_v15_tp_dir = os.path.join(base_dir, 'labels_v15_tp')
label_v15_dir = os.path.join(base_dir, 'labels_v15')
label_v14_sta_dir = os.path.join(label_ana_dir, 'labels_v14_sta')
label_v15_sta_dir = os.path.join(label_ana_dir, 'labels_v15_sta')
check_dir = r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1030/labels_analysis/label_v12_check'
datav15_dir =  r'/localnvme/data/billboard/all_data/mseg_c6/data7961_mseg_c6_1111_v15'

# %%
update_risk_by_ref(label_v14_dir, label_v15_tp_dir, os.path.join(check_dir, 'broken_no'), dst_risk='b-n')

# %%
update_risk_by_ref(label_v15_tp_dir, label_v15_dir, os.path.join(check_dir, 'broken_medium'), dst_risk='b-m')

# %%
copy_all(
    label_v15_dir,
    os.path.join(datav15_dir, 'labels'),
    image_dir,
    os.path.join(datav15_dir, 'images'),
)

# %%
output_dir = datav15_dir
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path)
copy_split(input_val_test_path, output_val_test_path)
copy_split(input_train_80p_path, output_train_80p_path)
copy_split(input_val_80p_path, output_val_80p_path)
copy_split(input_all_path, output_all_path)
copy_split(input_all_test_path, output_all_test_path)

shutil.copy(class_c6_path, os.path.join(output_dir, 'class.txt'))
shutil.copy(att_l3_path, os.path.join(output_dir, 'attribute.yaml'))

# %%
data_tf_pipline_new(datav15_dir, copy_list=['mseg_c5_l2'])

# %%
output_dir = datav15_dir.replace('mseg_c6', 'mseg_c5_l2')
output_train_test_path = os.path.join(output_dir, 'train_test.txt')
output_val_test_path = os.path.join(output_dir, 'val_test.txt')
output_train_80p_path = os.path.join(output_dir, 'train_80p_ref.txt')
output_val_80p_path = os.path.join(output_dir, 'val_80p_ref.txt')
output_all_path = os.path.join(output_dir, 'all.txt')
output_all_test_path = os.path.join(output_dir, 'all_test.txt')

copy_split(input_train_test_path, output_train_test_path, abs_path=True)
copy_split(input_val_test_path, output_val_test_path, abs_path=True)
copy_split(input_train_80p_path, output_train_80p_path, abs_path=True)
copy_split(input_val_80p_path, output_val_80p_path, abs_path=True)
copy_split(input_all_path, output_all_path, abs_path=True)
copy_split(input_all_test_path, output_all_test_path, abs_path=True)

# %%
yolo_sta(
    gt_dir=label_v14_dir,
    result_dir=label_v14_sta_dir,
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)

# %%
yolo_sta(
    gt_dir=label_v15_dir,
    result_dir=label_v15_sta_dir,
    class_path=class_file,
    attribute_path=attribute_file,
    seg=True,
)

# %%
# extract data80

# %%
import os
from att_tools import vis_matched_result
from yolo_tools import remove_conf, copy_ref_csv
from yolo_mask_crop import myolo_crop

# %%
datav15_dir = r'/localnvme/data/billboard/all_data/mseg_c5_l2/data7961_mseg_c5_l2_1111_v15'
data80_dir = r'/localnvme/data/billboard/all_data/mseg_c5_l2/data80_v15'
class_c5_path = r'/localnvme/data/billboard/class_c5.txt'
att_l2_path = r'/localnvme/data/billboard/attribute_l2.yaml'

input_image_dir = os.path.join(datav15_dir, 'images')
input_label_dir = os.path.join(datav15_dir, 'labels')
input_val_test_path = os.path.join(datav15_dir, 'val_test.txt')

data80_image_dir = os.path.join(data80_dir, 'images')
data80_label_dir = os.path.join(data80_dir, 'labels')
data80_result_analysis_dir = os.path.join(data80_dir, 'result_analysis')
data80_class_path = os.path.join(data80_dir, 'class.txt')
data80_att_path = os.path.join(data80_dir, 'attribute.yaml')

# %%
copy_ref_csv(input_image_dir, data80_image_dir, input_val_test_path)

# %%
copy_ref_csv(input_label_dir, data80_label_dir, input_val_test_path)

# %%
shutil.copy(class_c5_path, data80_class_path)
shutil.copy(att_l2_path, data80_att_path)

# %%
image_dir = data80_image_dir
label_dir = data80_label_dir
image_crop_dir = label_dir+'_crop'

# %%
myolo_crop(
    image_dir,
    label_dir,
    image_crop_dir,
    data80_class_path,
    attribute_file=data80_att_path,
    seg=True,
    annotation=False,
    save_method='attribute',
    only_defect=False,
    with_boundary=False,
    crop_method='with_background_box_shape'
)

# %%
val_dir = r'/localnvme/project/ultralytics/runs/msegment/val749/labels'
pred_dir = os.path.join(data80_dir, 'val749')

# %%
remove_conf(val_dir, pred_dir)

# %%
image_dir = data80_image_dir
label_dir = pred_dir
image_crop_dir = label_dir+'_crop'

# %%
myolo_crop(
    image_dir,
    label_dir,
    image_crop_dir,
    data80_class_path,
    attribute_file=data80_att_path,
    seg=True,
    annotation=False,
    save_method='attribute',
    only_defect=False,
    with_boundary=False,
    crop_method='with_background_box_shape'
)

# %%
vis_dir = os.path.join(data80_result_analysis_dir, 'vis')

# %%
vis_matched_result(
    data80_image_dir,
    data80_label_dir,
    pred_dir,
    vis_dir,
    data80_class_path,
    data80_att_path,
    with_conf=False,
    annotation=True,
    iou_thr=0.3,
    conf_threshold=0.4,
    defect_conf_threshold=0.001,
    filter_small=0.05,
    save_method='attribute',
    crop_method='with_background_box_shape',
)
# Out:
# mask cropping : 100%|██████████| 80/80 [00:16<00:00,  4.94it/s]
# 100%|██████████| 738/738 [00:00<00:00, 93558.90it/s]
# mask cropping : 100%|██████████| 80/80 [01:31<00:00,  1.15s/it]
# 100%|██████████| 7855/7855 [00:00<00:00, 176572.22it/s]
# copy: 100%|██████████| 2952/2952 [00:00<00:00, 4727.28it/s]
# copy: 100%|██████████| 31420/31420 [00:05<00:00, 6168.03it/s]
# read and process label: 100%|██████████| 80/80 [00:07<00:00, 10.07it/s]
